# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-K27/First_repo/blob/main/Hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(quotes)
# Out:
# [<table class="wikitable" style="text-align:center;">
# <caption>Народжуваність в межах сучасної України<sup class="reference" id="cite_ref-ukrstat1_31-2"><a href="#cite_note-ukrstat1-31">[22]</a></sup><sup class="reference" id="cite_ref-FOOTNOTEРашин_А._Г.1956_42-1"><a href="#cite_note-FOOTNOTEРашин_А._Г.1956-42">[31]</a></sup><sup class="reference" id="cite_ref-demoscope20170410_43-0"><a href="#cite_note-demoscope20170410-43">[32]</a></sup><sup class="reference" id="cite_ref-FOOTNOTEПтуха_М._В.1960_44-0"><a href="#cite_note-FOOTNOTEПтуха_М._В.1960-44">[33]</a></sup><sup class="reference" id="cite_ref-demoscope20161121_45-0"><a href="#cite_note-demoscope20161121-45">[34]</a></sup>
# </caption>
# <tbody><tr>
# <th>Рік
# </th>
# <th>Кількість народжень
# </th>
# <th>Коефіцієнт народжуваності
# </th>
# <th>Коефіцієнт фертильності
# </th></tr>
# <tr>
# <td>1860
# </td>
# <td>—
# </td>
# <td>~50,0
# </td>
# <td>—
# </td></tr>
# <tr>
# <td>1896
# </td>
# <td>—
# </td>
# <td>~47,5
# </td>
# ...

# %%
tmp = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8", attrs={"class": "wikitable collapsible collapsed", "style":"text-align: right"})
table = tmp[2]

# %%
table.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %%
table.shape
# Out:
# (28, 9)

# %%
table = table.replace({"—": np.nan},regex=True)

# %%
table.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
table[['1950','1960','1970','1990','2000','2012','2014','2019']]=table[['1950','1960','1970','1990','2000','2012','2014','2019']].astype('float').div(10)

# %%
table
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012   2014   2019
# 0                Крим  23.0  20.6  16.0  1.30  0.73  1.26    NaN    NaN
# 1           Вінницька  22.4  19.2  14.2  1.24  0.84  1.12  0.109  0.076
# 2           Волинська  24.7  25.0  17.9  1.53  1.12  1.48  0.141  0.101
# 3    Дніпропетровська  20.4  20.4  15.1  1.23  0.71  1.12  0.111  0.071
# 4            Донецька  27.1  21.4  14.0  1.09  0.61  0.98  0.082    NaN
# 5         Житомирська  26.1  22.3  15.9  1.29  0.89  1.22  0.120  0.079
# 6        Закарпатська  31.4  27.3  20.7  1.68  1.15  1.51  0.146  0.104
# 7          Запорізька  21.9  19.7  15.0  1.24  0.71  1.06  0.106  0.068
# 8   Івано-Франківська  24.3  24.8  18.2  1.55  1.03  1.24  0.122  0.088
# 9            Київська  20.4  18.9  15.6  1.23  0.73  1.22  0.121  0.080
# 10     Кіровоградська  21.6  17.1  14.5  1.26  0.79  1.10  0.108  0.068
# 11          Луганська  26.2  23.5  14.4  1.16  0.62  0.96  0.051    NaN
# ...

# %%
table.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
table=table.drop(27)

# %%
table[['1950','1960','1970','1990','2000','2012','2014','2019']] =table[['1950','1960','1970','1990','2000','2012','2014','2019']].fillna(value=table[['1950','1960','1970','1990','2000','2012','2014','2019']].mean(axis=0)).round(2)

# %%
table[['Регіон','2019']][table['2019']>table['2019'].mean()]
# Out:
#                Регіон  2019
# 2           Волинська  0.10
# 6        Закарпатська  0.10
# 8   Івано-Франківська  0.09
# 12          Львівська  0.09
# 14            Одеська  0.09
# 16         Рівненська  0.11
# 23        Чернівецька  0.09
# 25               Київ  0.11

# %%
table[['Регіон','2014']][table['2014']==table['2014'].max()]
# Out:
#           Регіон  2014
# 6   Закарпатська  0.15
# 16    Рівненська  0.15

# %%
plt.barh(table['Регіон'], table['2019'], height=0.7)

plt.xlabel("Коефіцієнт народжуваності", fontsize=13, color="midnightblue")
plt.ylabel("Регіон", fontsize=10, color="midnightblue")
plt.title("Коефіцієнт народжуваності в регіонах України (2019 р.)", fontsize=15)
plt.grid(color='grey', linestyle='-', axis='x', linewidth=1)
plt.show()
